# %% [markdown]
# <a href="https://colab.research.google.com/github/VU21CSEN0101426/python-/blob/module-4/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Checking Matplotlib Version

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.2.2

# %% [markdown]
# Draw a line in a diagram from position (0,0) to position (7,140):

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 7])
ypoints = np.array([0, 140])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Plotting x and y points

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([4, 12])
ypoints = np.array([6, 20])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Plotting Without Line

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 10])
ypoints = np.array([4, 20])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# Multiple Points

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4, 8, 10])
ypoints = np.array([3, 6, 9, 12])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Default X-Points

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 7, 0, 12, 9, 2])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# Markers

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 7, 2, 14])

plt.plot(ypoints, marker = 'o')
plt.show()

# %% [markdown]
# Mark each point with a star

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 10, 7, 14])

plt.plot(ypoints, marker = '*')
plt.show()

# %% [markdown]
# Format Strings fmt

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 14, 4, 20])

plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# Marker Size

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 14, 4, 20])

plt.plot(ypoints, marker = 'o', ms = 18)
plt.show()

# %% [markdown]
# Marker Color

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 14, 4, 20])

plt.plot(ypoints, marker = 'o', ms = 18, mec = 'k')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 14, 4, 20])

plt.plot(ypoints, marker = 'o', ms = 18, mfc = 'y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 18, mec = 'k', mfc = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 14, 7, 20])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
plt.show()

# %% [markdown]
# Linestyle

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 14, 4, 20])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 14, 4, 20])

plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 14, 4, 20])

plt.plot(ypoints, ls = ':')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 14, 4, 20])

plt.plot(ypoints, linestyle = 'dashdot')
plt.show()

# %% [markdown]
# Line Color

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 14, 4, 20])

plt.plot(ypoints, color = 'k')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 14, 4, 20])

plt.plot(ypoints, c = 'hotpink')
plt.show()

# %% [markdown]
# Line Width

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 14, 4, 15])

plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %% [markdown]
# Multiple Lines

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 10, 5, 20])
y2 = np.array([5, 7, 3, 23])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# Create Labels for a Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# Create a Title for a Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# Set Font Properties for Title and Labels

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# Position the Title

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %% [markdown]
# Add Grid Lines to a Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %% [markdown]
# Specify Which Grid Lines to Display

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %% [markdown]
# Set Line Properties for the Grid

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %% [markdown]
# Display Multiple Plots

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# Title

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %% [markdown]
# Super Title

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# Creating Scatter Plots

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# Compare Plots

# %%
import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# Colors

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %% [markdown]
# Color Each Dot

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# ColorMap

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %% [markdown]
# Size

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %% [markdown]
# Alpha

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %%
Combine Color Size and Alpha

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# Creating Bars

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 7, 2, 20])

plt.bar(x,y)
plt.show()

# %% [markdown]
# Horizontal Bars

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 6, 2, 13])

plt.barh(x, y)
plt.show()

# %% [markdown]
# Bar Color

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 5, 21, 20])

plt.bar(x, y, color = "y")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 5, 21, 20])

plt.bar(x, y, color = "hotpink")
plt.show()

# %% [markdown]
# Color Hex

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "#4CAF50")
plt.show()

# %% [markdown]
# Bar Width

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.5)
plt.show()

# %% [markdown]
# Bar Height

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.3)
plt.show()

# %% [markdown]
# Histogram

# %%
import numpy as np

x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [165.54388149 166.36388563 188.04427964 167.48278526 180.50759675
#  162.75829256 172.61080982 184.96325664 155.82214547 172.74588079
#  164.33252939 147.504777   169.4744381  167.4911839  174.03974555
#  185.93699095 187.41902467 166.57958691 160.97927351 187.6654934
#  164.20512528 175.92696435 165.40218425 156.79487421 165.56243201
#  177.173477   163.20811976 171.41066161 177.14526627 181.74258951
#  172.51606948 174.16853943 155.89918732 158.22075738 177.32871834
#  173.13798777 158.16109229 167.09958615 148.41874947 154.0521056
#  175.36461344 176.96042555 163.63679304 177.84675733 167.39174036
#  173.73083899 161.07279329 176.60207502 158.92816282 173.16115252
#  171.53617217 172.05993484 166.74474312 163.29958537 171.14824859
#  153.64676935 169.66467622 173.69278862 169.18046226 164.61441908
#  174.7931033  170.63240645 158.47719534 199.85673276 167.90853424
#  166.45104509 167.60366743 171.9410427  189.44537274 171.73901947
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(120, 50, 350)

plt.hist(x)
plt.show()

# %% [markdown]
# Creating Pie Charts

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([20, 25, 30, 8])

plt.pie(y)
plt.show()

# %% [markdown]
# Labels

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([20, 25, 30, 8])
mylabels = ["lily", "sunflower", "rose", "jasmine"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# Start Angle

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([20, 25, 30, 8])
mylabels = ["lily", "sunflower", "rose", "jasmine"]

plt.pie(y, labels = mylabels, startangle = 45)
plt.show()

# %% [markdown]
# Explode

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([20, 25, 30, 8])
mylabels = ["lily", "sunflower", "rose", "jasmine"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# Shadow

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([20, 25, 30, 8])
mylabels = ["lily", "sunflower", "rose", "jasmine"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# Colors

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([20, 25, 30, 8])
mylabels = ["lily", "sunflower", "rose", "jasmine"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# Legend

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([20, 25, 30, 8])
mylabels = ["lily", "sunflower", "rose", "jasmine"]


plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()

# %% [markdown]
# Legend With Header

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([20, 25, 30, 8])
mylabels = ["lily", "sunflower", "rose", "jasmine"]


plt.pie(y, labels = mylabels)
plt.legend()
plt.show()
